# %% [markdown]
# # Model Monitoring: Lab Notebook
#
# This notebook is for you to use for visualization and analysis of your monitoring results.
#
# > DUPLICATE THIS COLAB TO START WORKING ON IT. Using File > Save a copy to drive.
#
# You won't need a GPU for this notebook.
#
# ---

# %%
import numpy 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# ===========================
# FILL ME OUT
# 
# Fill out each list below with 8 scores, one for 
# each snapshot. Use the output from `monitor.py`. 
# 
# Afterwards, plot them using Matplotlib as line plots. 
# Please label the x and y axes accordingly.
ks_scores = []
hist_scores = []
outlier_scores = []
ks_scores=[0.7946637387576738, 0.8881734182535203, 0.07761108123267829, 3.5127087833331994e-13, 6.368984280614877e-36, 2.6027134195177023e-57, 4.64927301850743e-55, 6.3151556458138154e-52]
hist_scores=[0.9700000000000001, 0.9740000000000001, 0.944, 0.833, 0.7170000000000001, 0.6439999999999999, 0.649, 0.6599999999999999]
outlier_scores=[6.303348653972418, 6.687428290444187, 26.80722891566265, 38.8896448496394, 52.89544235924932, 64.40531177829098, 64.19354838709677, 66.03202077022934]

snapshots = range(1,9)
# ===========================

# %%
plt.plot(snapshots,hist_scores)
plt.xlabel("stream snapshots")
plt.ylabel("hist - scores")
plt.show()

# %%
plt.plot(snapshots,ks_scores)
plt.xlabel("stream snapshots")
plt.ylabel("ks - scores")
plt.show()

# %%
plt.plot(snapshots,outlier_scores)
plt.xlabel("stream snapshots")
plt.ylabel("outlier - scores")
plt.show()

# %% [markdown]
# ## Analysis
#
# Describe below what patterns you see. At which snapshot do you believe some distribution shift has occurred? When would you declare that improvements to the data and/or model need to be made?
#
# **From third snaapshot, we can see the distribution starts to shift slowly, and in the 6th snapshot we can see the train and test data distributions have completely diverged.**
#
# Next, if you haven't figured it out already, let's see what is causing this distribution shift. Look at the raw data files in `data/stream/stream*.csv`. Describe below what is happening!
#
# **in the 3rd snapshot, we see the emergence of review comments in spanish, and in the 6th snapshot, the spanish review percentage increases significantly**
